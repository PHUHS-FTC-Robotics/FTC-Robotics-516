# %%
# imports needed to read and test we have necessary test data
import pandas as pd

# %%
df = pd.read_csv("../data/dummy_telemetry.csv")
df
# Out:
#    time_seconds  battery_voltage  motor_power
# 0             0             12.6         0.20
# 1             1             12.5         0.45
# 2             2             12.4         0.70
# 3             3             12.3         0.85
# 4             4             12.2         0.60
